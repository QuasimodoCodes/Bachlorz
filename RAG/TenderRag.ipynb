# %%
import pymongo
import requests

client = pymongo.MongoClient('mongodb+srv://vctrfgr1:ALJ9Q9o32r2PXOWJ@cluster0.imdpm.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0')
db = client.sample_mflix
collection = db.movies


hf_token ="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"
embeding_url = "https://api-inference.huggingface.co/pipeline/feature-extraction/sentence-transformers/all-MiniLM-L6-v2"

def generate_embeding(text: str) -> list[float]:
    response = requests.post(
        embeding_url, 
        headers={"Authorization": f"Bearer {hf_token}"}, 
        json={"inputs": text}
    )

    if response.status_code != 200:
        raise Exception(f"Request failed with status code {response.status_code}: {response.text}")
    return response.json()

for doc in collection.find("plot":["$exists: true"]):limit (50):
    doc['plot_embeding'] = generate_embeding(doc['plot'])
    collection.replace_one({"_id": doc["_id"]}, doc)
# Out:
# [-0.038177166134119034, 0.03291111811995506, -0.005459434352815151, 0.014369940385222435, -0.04029102623462677, -0.11653245240449905, 0.031687721610069275, 0.0019117096671834588, -0.04262232407927513, 0.029168102890253067, 0.04242667928338051, 0.03204173222184181, 0.029844751581549644, 0.010980352759361267, -0.05393955856561661, -0.05027727037668228, -0.02350788004696369, 0.010779389180243015, -0.13770794868469238, 0.0041149696335196495, 0.029333120211958885, 0.06684111803770065, -0.015389388427138329, 0.04843766614794731, -0.08814975619316101, -0.012726838700473309, 0.041409023106098175, 0.040831558406353, -0.05015585198998451, -0.058125026524066925, 0.048801567405462265, 0.06889018416404724, 0.05874694511294365, 0.008730964735150337, -0.015918219462037086, 0.08514193445444107, -0.07814742624759674, -0.0775168165564537, 0.020723750814795494, 0.016194269061088562, 0.03251056373119354, -0.053488876670598984, -0.06222880631685257, -0.024314651265740395, 0.007412799168378115, 0.02397773
# ...
